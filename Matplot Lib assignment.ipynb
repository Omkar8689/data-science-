# %% [raw]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [raw]
# Mataplotlib is the liabrary in the python used to represent the data in graphical from.
# 1.Scattered form
# 2.historick form
# 3.Bar graph
# 4.Line grgaph
# 5.Pie Chart

# %% [raw]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
#Note: Also add title, xlabel, and ylabel to the plot.

# %% [raw]
# Scatter plot is the type of ploting used to plot the data with scattered format.

# %%
import numpy as np
import matplotlib.pyplot as npt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
npt.scatter(x,y)

# %% [raw]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %% [raw]
# The subplot() function in Matplotlib is used to create a grid of subplots within a single figure. It allows you to arrange multiple plots or charts in a single figure canvas, which is particularly useful when you want to compare or display multiple sets of data side by side or in a grid layout.
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])


plt.figure(figsize=(12, 8))


plt.subplot(2, 2, 1)
plt.plot(x, y1, label='Line 1')
plt.title('Line 1')
plt.legend()


plt.subplot(2, 2, 2)
plt.plot(x, y2, label='Line 2', color='orange')
plt.title('Line 2')
plt.legend()


plt.subplot(2, 2, 3)
plt.plot(x, y3, label='Line 3', color='green')
plt.title('Line 3')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(x, y4, label='Line 4', color='red')
plt.title('Line 4')
plt.legend()


plt.tight_layout()


plt.show()

# %%
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %% [raw]
# Bar plot is the type of the graph plotting used to describe the data in graphical form.

# %%
import numpy as np
import matplotlib.pyplot as plt
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])


plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>
